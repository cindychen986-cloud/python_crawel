# %%
print("Hello! python!")
# Out:
# 執行具有 'python_crawel (Python 3.10.19)' 的儲存格需要 ipykernel 套件。
#
# 將 'ipykernel' 安裝到 Python 環境中。
#
# 命令: 'c:/Users/User/Documents/github/python_crawel/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
