# %%
chinese = 78
chinese = chinese + 5
english = 92
math = 67

total = chinese + english + math

average = total / 3
average
# Out:
# 80.66666666666667

# %%
# 複合指定運算子
# 導入函式庫math使用其中的開平方根函式
import math

chinese = 78
chinese += 5
chinese *= 10

# chinese 開平方根
# 使用round取小數點後2位
value = math.sqrt(chinese)
value = round(value,ndigits=2)

# %%
# 複合指定運算子
import math

chinese = 78
chinese += 5
chinese *= 10

# chinese 開平方根
value = round(math.sqrt(chinese),ndigits=2)
value
# Out:
# 28.81

# %%
#外部套件 NumPy
#科學家套件 SciPy
